# %% [markdown]
# # Week 2 Assignment: CIFAR-10 Autoencoder
#
# For this week, you will create a convolutional autoencoder for the [CIFAR10](https://www.tensorflow.org/datasets/catalog/cifar10) dataset. You are free to choose the architecture of your autoencoder provided that the output image has the same dimensions as the input image.
#
# After training, your model should meet loss and accuracy requirements when evaluated with the test dataset. You will then download the model and upload it in the classroom for grading.
#
# Let's begin!

# %% [markdown]
# ***Important:*** *This colab notebook has read-only access so you won't be able to save your changes. If you want to save your work periodically, please click `File -> Save a Copy in Drive` to create a copy in your account, then work from there.*

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

from keras.models import Sequential

# %% [markdown]
# ## Load and prepare the dataset
#
# The [CIFAR 10](https://www.tensorflow.org/datasets/catalog/cifar10) dataset already has train and test splits and you can use those in this exercise. Here are the general steps:
#
# * Load the train/test split from TFDS. Set `as_supervised` to `True` so it will be convenient to use the preprocessing function we provided.
# * Normalize the pixel values to the range [0,1], then return `image, image` pairs for training instead of `image, label`. This is because you will check if the output image is successfully regenerated after going through your autoencoder.
# * Shuffle and batch the train set. Batch the test set (no need to shuffle).

# %%
# preprocessing function
def map_image(image, label):
  image = tf.cast(image, dtype=tf.float32)
  image = image / 255.0

  return image, image # dataset label is not used. replaced with the same image input.

# parameters
BATCH_SIZE = 128
SHUFFLE_BUFFER_SIZE = 1024


### START CODE HERE (Replace instances of `None` with your code) ###

# use tfds.load() to fetch the 'train' split of CIFAR-10
train_dataset = tfds.load('cifar10', as_supervised=True, split="train")

# preprocess the dataset with the `map_image()` function above
train_dataset = train_dataset.map(map_image)

# shuffle and batch the dataset
train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)


# use tfds.load() to fetch the 'test' split of CIFAR-10
test_dataset = tfds.load('cifar10', as_supervised=True, split="test")

# preprocess the dataset with the `map_image()` function above
test_dataset = test_dataset.map(map_image)

# batch the dataset
test_dataset = test_dataset.batch(BATCH_SIZE)

### END CODE HERE ###
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/cifar10/3.0.2 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/cifar10/3.0.2...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/cifar10/incomplete.X41R8D_3.0.2/cifar10-train.tfrecord*...:   0%|         …
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/cifar10/incomplete.X41R8D_3.0.2/cifar10-test.tfrecord*...:   0%|          …
# Dataset cifar10 downloaded and prepared to /root/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.

# %% [markdown]
# ## Build the Model
#
# Create the autoencoder model. As shown in the lectures, you will want to downsample the image in the encoder layers then upsample it in the decoder path. Note that the output layer should be the same dimensions as the original image. Your input images will have the shape `(32, 32, 3)`. If you deviate from this, your model may not be recognized by the grader and may fail.
#
# We included a few hints to use the Sequential API below but feel free to remove it and use the Functional API just like in the ungraded labs if you're more comfortable with it. Another reason to use the latter is if you want to visualize the encoder output. As shown in the ungraded labs, it will be easier to indicate multiple outputs with the Functional API. That is not required for this assignment though so you can just stack layers sequentially if you want a simpler solution.

# %%
# suggested layers to use. feel free to add or remove as you see fit.
from keras.layers import Conv2D, UpSampling2D

# use the Sequential API (you can remove if you want to use the Functional API)
# model = Sequential()

### START CODE HERE ###
# use `model.add()` to add layers (if using the Sequential API)
inputs = tf.keras.layers.Input(shape=(32, 32, 3,))
conv_1 = tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(inputs)
max_pool_1 = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(conv_1)
conv_2 = tf.keras.layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(max_pool_1)
max_pool_2 = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(conv_2)

bottle_neck = tf.keras.layers.Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same')(max_pool_2)
# encoder_visualization = tf.keras.layers.Conv2D(filters=1, kernel_size=(3,3), activation='sigmoid', padding='same')(bottle_neck)

conv_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(bottle_neck)
up_sample_1 = tf.keras.layers.UpSampling2D(size=(2,2))(conv_3)
conv_4 = tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(up_sample_1)
up_sample_2 = tf.keras.layers.UpSampling2D(size=(2,2))(conv_4)
decoder_output = tf.keras.layers.Conv2D(filters=3, kernel_size=(3,3), activation='sigmoid', padding='same')(up_sample_2)


model = tf.keras.Model(inputs =inputs, outputs=decoder_output)
# encoder_model = tf.keras.Model(inputs=inputs, outputs=encoder_visualization)


### END CODE HERE ###

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 8, 8, 128)      │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 16, 16, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 32, 32, 3)      │         1,731 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 741,379 (2.83 MB)
#  Trainable params: 741,379 (2.83 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Configure training parameters
#
# We have already provided the optimizer, metrics, and loss in the code below.

# %%
# Please do not change the model.compile() parameters
model.compile(optimizer='adam', metrics=['accuracy'], loss='mean_squared_error')

# %% [markdown]
# ## Training
#
# You can now use [model.fit()](https://keras.io/api/models/model_training_apis/#fit-method) to train your model. You will pass in the `train_dataset` and you are free to configure the other parameters. As with any training, you should observe the loss generally going down and the accuracy going up at each epoch. If not, please revisit the previous sections to find possible bugs.
#
# *Note: If you get a `dataset length is infinite` error. Please check how you defined `train_dataset`. You might have included a [method that repeats the dataset indefinitely](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#repeat).*

# %%
# parameters
train_steps = len(train_dataset) // BATCH_SIZE
val_steps = len(test_dataset) // BATCH_SIZE

### START CODE HERE ###
model.fit(train_dataset, steps_per_epoch=train_steps, validation_data=test_dataset, validation_steps=val_steps, epochs=100)
### END CODE HERE ###
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.4715 - loss: 0.0608 - val_accuracy: 0.5023 - val_loss: 0.0665
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step - accuracy: 0.5132 - loss: 0.0661 - val_accuracy: 0.3727 - val_loss: 0.0537
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step - accuracy: 0.4002 - loss: 0.0557 - val_accuracy: 0.4520 - val_loss: 0.0500
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step - accuracy: 0.4635 - loss: 0.0477 - val_accuracy: 0.5322 - val_loss: 0.0376
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 296ms/step - accuracy: 0.4930 - loss: 0.0393 - val_accuracy: 0.4423 - val_loss: 0.0367
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 343ms/step - accuracy: 0.4646 - loss: 0.0348 - val_accuracy: 0.5388 - val_loss: 0.0309
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 343ms/step - accuracy: 0.5332 - loss: 0.0315 - val_accuracy: 0.5993 - val_loss: 0.0272
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 317ms/step - accuracy: 0.5886 - loss: 0.0280 - val_accuracy: 0.5590 - val_loss: 0.0242
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step - accuracy: 0.5597 - loss: 0.0248 - val_accuracy: 0.6141 - val_loss: 0.0261
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - accuracy: 0.6051 - loss: 0.0246 - val_accuracy: 0.6234 - val_loss: 0.0237
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.5815 - loss: 0.0222 - val_accuracy: 0.6099 - val_loss: 0.0215
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 290ms/step - accuracy: 0.6070 - loss: 0.0206 - val_accuracy: 0.6003 - val_loss: 0.0188
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 291ms/step - accuracy: 0.6006 - loss: 0.0183 - val_accuracy: 0.6393 - val_loss: 0.0168
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 290ms/step - accuracy: 0.6554 - loss: 0.0167 - val_accuracy: 0.6044 - val_loss: 0.0158
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step - accuracy: 0.6069 - loss: 0.0151 - val_accuracy: 0.6248 - val_loss: 0.0161
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 300ms/step - accuracy: 0.6231 - loss: 0.0162 - val_accuracy: 0.6266 - val_loss: 0.0139
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 342ms/step - accuracy: 0.6239 - loss: 0.0149 - val_accuracy: 0.6387 - val_loss: 0.0141
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step - accuracy: 0.6357 - loss: 0.0155 - val_accuracy: 0.6471 - val_loss: 0.0146
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 337ms/step - accuracy: 0.6528 - loss: 0.0140 - val_accuracy: 0.6600 - val_loss: 0.0132
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.6542 - loss: 0.0130 - val_accuracy: 0.6483 - val_loss: 0.0116
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 338ms/step - accuracy: 0.6313 - loss: 0.0120 - val_accuracy: 0.6697 - val_loss: 0.0116
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 338ms/step - accuracy: 0.6620 - loss: 0.0119 - val_accuracy: 0.6554 - val_loss: 0.0122
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 338ms/step - accuracy: 0.6779 - loss: 0.0117 - val_accuracy: 0.6811 - val_loss: 0.0120
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step - accuracy: 0.6650 - loss: 0.0114 - val_accuracy: 0.6889 - val_loss: 0.0110
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 661ms/step - accuracy: 0.6792 - loss: 0.0112 - val_accuracy: 0.7014 - val_loss: 0.0099
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 676ms/step - accuracy: 0.7257 - loss: 0.0101 - val_accuracy: 0.6836 - val_loss: 0.0105
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 290ms/step - accuracy: 0.6921 - loss: 0.0099 - val_accuracy: 0.7186 - val_loss: 0.0105
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step - accuracy: 0.7026 - loss: 0.0106 - val_accuracy: 0.6699 - val_loss: 0.0099
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step - accuracy: 0.7029 - loss: 0.0097 - val_accuracy: 0.7168 - val_loss: 0.0094
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step - accuracy: 0.7048 - loss: 0.0088 - val_accuracy: 0.7304 - val_loss: 0.0092
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step - accuracy: 0.7325 - loss: 0.0092 - val_accuracy: 0.7275 - val_loss: 0.0085
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 338ms/step - accuracy: 0.7121 - loss: 0.0087 - val_accuracy: 0.6961 - val_loss: 0.0094
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 338ms/step - accuracy: 0.7116 - loss: 0.0088 - val_accuracy: 0.7188 - val_loss: 0.0082
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step - accuracy: 0.7173 - loss: 0.0085 - val_accuracy: 0.7365 - val_loss: 0.0087
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 303ms/step - accuracy: 0.7313 - loss: 0.0085 - val_accuracy: 0.7399 - val_loss: 0.0079
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step - accuracy: 0.7168 - loss: 0.0080 - val_accuracy: 0.7424 - val_loss: 0.0078
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 292ms/step - accuracy: 0.7471 - loss: 0.0075 - val_accuracy: 0.7451 - val_loss: 0.0076
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step - accuracy: 0.7441 - loss: 0.0074 - val_accuracy: 0.7384 - val_loss: 0.0077
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step - accuracy: 0.7311 - loss: 0.0096 - val_accuracy: 0.7237 - val_loss: 0.0213
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step - accuracy: 0.7263 - loss: 0.0181 - val_accuracy: 0.7312 - val_loss: 0.0092
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.7209 - loss: 0.0104 - val_accuracy: 0.7066 - val_loss: 0.0110
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 690ms/step - accuracy: 0.6828 - loss: 0.0111 - val_accuracy: 0.7135 - val_loss: 0.0114
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 343ms/step - accuracy: 0.7032 - loss: 0.0110 - val_accuracy: 0.7217 - val_loss: 0.0102
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 659ms/step - accuracy: 0.7147 - loss: 0.0097 - val_accuracy: 0.7380 - val_loss: 0.0094
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 691ms/step - accuracy: 0.7359 - loss: 0.0091 - val_accuracy: 0.7214 - val_loss: 0.0085
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step - accuracy: 0.7277 - loss: 0.0083 - val_accuracy: 0.7359 - val_loss: 0.0079
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 338ms/step - accuracy: 0.7244 - loss: 0.0078 - val_accuracy: 0.7427 - val_loss: 0.0078
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.7564 - loss: 0.0075 - val_accuracy: 0.7294 - val_loss: 0.0078
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - accuracy: 0.7370 - loss: 0.0076 - val_accuracy: 0.7502 - val_loss: 0.0075
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 341ms/step - accuracy: 0.7523 - loss: 0.0070 - val_accuracy: 0.7253 - val_loss: 0.0072
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step - accuracy: 0.7442 - loss: 0.0071 - val_accuracy: 0.7565 - val_loss: 0.0073
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step - accuracy: 0.7622 - loss: 0.0069 - val_accuracy: 0.7657 - val_loss: 0.0071
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step - accuracy: 0.7695 - loss: 0.0071 - val_accuracy: 0.7442 - val_loss: 0.0069
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step - accuracy: 0.7532 - loss: 0.0067 - val_accuracy: 0.7524 - val_loss: 0.0068
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 302ms/step - accuracy: 0.7549 - loss: 0.0069 - val_accuracy: 0.7575 - val_loss: 0.0069
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 360ms/step - accuracy: 0.7471 - loss: 0.0067 - val_accuracy: 0.7608 - val_loss: 0.0067
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 372ms/step - accuracy: 0.7489 - loss: 0.0064 - val_accuracy: 0.7577 - val_loss: 0.0066
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 681ms/step - accuracy: 0.7649 - loss: 0.0067 - val_accuracy: 0.7644 - val_loss: 0.0066
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step - accuracy: 0.7651 - loss: 0.0068 - val_accuracy: 0.7669 - val_loss: 0.0066
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 304ms/step - accuracy: 0.7585 - loss: 0.0066 - val_accuracy: 0.7717 - val_loss: 0.0063
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 296ms/step - accuracy: 0.7644 - loss: 0.0065 - val_accuracy: 0.7667 - val_loss: 0.0065
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step - accuracy: 0.7702 - loss: 0.0062 - val_accuracy: 0.7678 - val_loss: 0.0062
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step - accuracy: 0.7765 - loss: 0.0062 - val_accuracy: 0.7657 - val_loss: 0.0064
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.7754 - loss: 0.0067 - val_accuracy: 0.7538 - val_loss: 0.0064
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 308ms/step - accuracy: 0.7551 - loss: 0.0066 - val_accuracy: 0.7596 - val_loss: 0.0061
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step - accuracy: 0.7631 - loss: 0.0061 - val_accuracy: 0.7580 - val_loss: 0.0060
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 294ms/step - accuracy: 0.7678 - loss: 0.0061 - val_accuracy: 0.7674 - val_loss: 0.0061
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 296ms/step - accuracy: 0.7841 - loss: 0.0060 - val_accuracy: 0.7751 - val_loss: 0.0060
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.7609 - loss: 0.0059 - val_accuracy: 0.7781 - val_loss: 0.0058
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step - accuracy: 0.7777 - loss: 0.0059 - val_accuracy: 0.7708 - val_loss: 0.0060
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.7742 - loss: 0.0067 - val_accuracy: 0.7742 - val_loss: 0.0100
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.7765 - loss: 0.0084 - val_accuracy: 0.7696 - val_loss: 0.0079
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step - accuracy: 0.7631 - loss: 0.0072 - val_accuracy: 0.7220 - val_loss: 0.0068
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 671ms/step - accuracy: 0.7592 - loss: 0.0070 - val_accuracy: 0.7793 - val_loss: 0.0061
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step - accuracy: 0.7550 - loss: 0.0063 - val_accuracy: 0.7731 - val_loss: 0.0064
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step - accuracy: 0.7696 - loss: 0.0061 - val_accuracy: 0.7377 - val_loss: 0.0059
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 291ms/step - accuracy: 0.7664 - loss: 0.0059 - val_accuracy: 0.7844 - val_loss: 0.0059
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step - accuracy: 0.7907 - loss: 0.0059 - val_accuracy: 0.7893 - val_loss: 0.0059
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 341ms/step - accuracy: 0.7824 - loss: 0.0059 - val_accuracy: 0.7812 - val_loss: 0.0058
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 292ms/step - accuracy: 0.7712 - loss: 0.0059 - val_accuracy: 0.7665 - val_loss: 0.0057
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step - accuracy: 0.7714 - loss: 0.0057 - val_accuracy: 0.7799 - val_loss: 0.0056
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 344ms/step - accuracy: 0.7685 - loss: 0.0057 - val_accuracy: 0.7768 - val_loss: 0.0055
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step - accuracy: 0.7761 - loss: 0.0055 - val_accuracy: 0.7778 - val_loss: 0.0054
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 341ms/step - accuracy: 0.7767 - loss: 0.0054 - val_accuracy: 0.7706 - val_loss: 0.0054
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step - accuracy: 0.7901 - loss: 0.0055 - val_accuracy: 0.7773 - val_loss: 0.0054
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 341ms/step - accuracy: 0.7740 - loss: 0.0055 - val_accuracy: 0.7788 - val_loss: 0.0055
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 303ms/step - accuracy: 0.7753 - loss: 0.0055 - val_accuracy: 0.7878 - val_loss: 0.0052
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step - accuracy: 0.7781 - loss: 0.0055 - val_accuracy: 0.7778 - val_loss: 0.0058
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 294ms/step - accuracy: 0.7852 - loss: 0.0055 - val_accuracy: 0.7750 - val_loss: 0.0052
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step - accuracy: 0.7910 - loss: 0.0052 - val_accuracy: 0.7687 - val_loss: 0.0054
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 676ms/step - accuracy: 0.7702 - loss: 0.0053 - val_accuracy: 0.7828 - val_loss: 0.0051
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step - accuracy: 0.7788 - loss: 0.0053 - val_accuracy: 0.7844 - val_loss: 0.0052
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 292ms/step - accuracy: 0.7833 - loss: 0.0052 - val_accuracy: 0.7854 - val_loss: 0.0051
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 301ms/step - accuracy: 0.7904 - loss: 0.0051 - val_accuracy: 0.7945 - val_loss: 0.0051
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - accuracy: 0.8071 - loss: 0.0052 - val_accuracy: 0.7891 - val_loss: 0.0052
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 289ms/step - accuracy: 0.7711 - loss: 0.0055 - val_accuracy: 0.7898 - val_loss: 0.0055
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 297ms/step - accuracy: 0.7770 - loss: 0.0054 - val_accuracy: 0.7617 - val_loss: 0.0053
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 296ms/step - accuracy: 0.7591 - loss: 0.0051 - val_accuracy: 0.7749 - val_loss: 0.0053
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.7718 - loss: 0.0054 - val_accuracy: 0.7730 - val_loss: 0.0050
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 294ms/step - accuracy: 0.7721 - loss: 0.0049 - val_accuracy: 0.7716 - val_loss: 0.0050

# %% [markdown]
# ## Model evaluation
#
# You can use this code to test your model locally before uploading to the grader. To pass, your model needs to satisfy these two requirements:
#
# * loss must be less than 0.01
# * accuracy must be greater than 0.6

# %%
result = model.evaluate(test_dataset, steps=10)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7711 - loss: 0.0049

# %% [markdown]
# If you did some visualization like in the ungraded labs, then you might see something like the gallery below. This part is not required.

# %% [markdown]
# <img src="https://storage.googleapis.com/tensorflow-3-public/assets/images/autoencoder.png" width="75%" height="75%"/>

# %% [markdown]
# ## Save the Model
#
# Once you're satisfied with the results, you can save your model and upload it to the grader in Coursera. Please run all succeeding cells to ensure that you will have a gradable submission. Otherwise, you might get this error message:
#
# `There was a problem grading your submission. Check stderr for more details.`
#
# First, save the model file in your Colab workspace.

# %%
# Save the model you just trained
model.save("mymodel.keras")

# %%
# You can also use this cell as a shortcut for downloading your model
from google.colab import files
files.download("mymodel.keras")

# %% [markdown]
# **Congratulations on completing this week's assignment!**
